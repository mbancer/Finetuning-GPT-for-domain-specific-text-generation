# %% [markdown]
# In this notebook I load and train the GPT-2 model by OpenAI on various datasets: scientific abstracts, news and novels. I save the trained models (checkpoints) for further analysis. I then generate chunk of text for further analysis. I rely on the *gpt-2-simple* library for finetuning and generating the text.

# %% [markdown]
# ## Loading the baseline GPT-2 model and datasets

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# Firstly, I download the model. I choose the small version with 124M parameters for simplicity.

# %%
gpt2.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 603Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 3.23Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 325Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:14, 34.5Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 385Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 3.89Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 3.86Mit/s]

# %% [markdown]
# I mount the google drive to be able to load the datasets and save checkpoints later:

# %%
gpt2.mount_gdrive()
# Out:
# Mounted at /content/drive

# %%
for d in ['abstracts', 'news', 'novels']:
  gpt2.copy_file_from_gdrive('data_' + d + '.txt')

# %% [markdown]
# ## Finetuning the model on a custom dataset
#
# For finetuning I use Adam optimizer, learning rate 0.0001 and follow 400 steps  (these and other parameters are chosen as optimal based on the model's performance).

# %%
def finetune_on_dataset(d):
  session = gpt2.start_tf_sess()
  gpt2.finetune(session,
                dataset='data_' + d + '.txt',
                model_name='124M',
                steps=400,
                restore_from='latest',
                run_name='run_' + d,
                learning_rate=0.0001,
                optimizer='adam',
                print_every=10,
                sample_every=100,
                sample_length=900,
                save_every=400
                )

  gpt2.copy_checkpoint_to_gdrive(run_name='run_' + d)

# %%
#d = 'abstracts', 'novels', 'news'
finetune_on_dataset('news')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
# dataset has 210264 tokens
# Training...
# [10 | 28.76] loss=2.45 avg=2.45
# [20 | 51.72] loss=2.67 avg=2.56
# [30 | 74.90] loss=2.92 avg=2.68
# [40 | 97.77] loss=2.73 avg=2.69
# [50 | 120.59] loss=2.20 avg=2.59
# [60 | 143.58] loss=2.45 avg=2.57
# [70 | 166.57] loss=2.01 avg=2.49
# [80 | 189.47] loss=2.12 avg=2.44
# [90 | 212.38] loss=1.90 avg=2.38
# [100 | 235.35] loss=1.86 avg=2.32
# ======== SAMPLE 1 ========
#  of the European Union and the Netherlands.
#
#
#
#
#
#
#
# The European Union negotiated a free trade agreement with 11 countries on Thursday night, which the United States administration hailed as an important step toward a better trade deal. Brazil and Mexico announced that they would join the deal, with the United Kingdom announcing on Tuesday it would be part of the deal by the end of the year.
#
#
#
#
#
#
#
#
#
#
# For more than a century Mexico has been Mexico City’s most central trading partner. It’s the only city in the United States that lacks a publicly traded port, allowing it to export goods that come from countries such as Canada, Mexico and New Zealand, and is also home to the U.S. border. Since 2002, the city has seen its trade with the United States triple, from $30.6 billion to $210.7 billion.
#
# But in recent years, Mexico’s economic dominance has come at a price. For workers at the city’s factories, wages have become less than American workers’s wages.
#
#
#
#
#
# There is also the problem of corruption: The city has long known that the money it makes from the local government’s spending and purchases — often from private businesses — is likely to flow to the United States in what the federal government calls a “debt spiral” — the government paying interest to its holdings that fund public services.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The United States has a reputation of being easy to get around — everything a U.S. travel agent can ask for is free on the country’s huge international travel network. But here in the United States, a company called Zara Travel Co. specializes in delivering and vetting travelers on their way to and from the U.S. — making it a tough place to get around without getting your ticket. But here in the United States, the travel agent you choose — the travel agent, not you — is the main driver of your trip — the agent. In other words, the one who has you on a mission — making and receiving a call through the system.
#
# On Nov. 3, Zara Travel Co. launched a special initiative called “The Zara Planner for U.S. Citizens,” known as Pledge. It has become the go-to strategy for citizens of many other countries who seek international travel. And it works, too. The plan shows you where you can get to, and from, hotels, food restaurants, airports, casinos, schools, recreation centers and other public facilities.
# For more information, see “The Zarad-i-Ayyara Planner for U.S. Citizens,” and ““The United States, Traveling Well”
# Updated June 18
#  The United States has become the most trafficked place in the world for asylum seekers, with the country making up almost 30 percent of all asylum-seekers registered in this year’s State of the Union address. The data is not complete for a large swath of countries — particularly countries that have enacted tough travel limits that keep them from finding stable, legal crossings — but it is a starting point. Here are some places that are reporting their most trafficked countries.
# ””
#  Libya 41.9
#  Turkey 41.4
#  Thailand 30.5
#  Libya 51.4
#
# ””
#
# Countries with the least restrictive policies on asylum seekers
# ””” Most heavily trafficked countries — with or without restrictions or restrictions
# ””” Most heavily trafficked countries with the least restrictive policies on asylum seekers
# ””” (1) India (down from 51.4 percent of total asylum seekers on March 9)
# ”””” Most heavily trafficked countries that have no or minimal restrictions (2) Australia (down from 51.4 percent on March 8, up 15.1 percent on April 4) Brazil (down from 50.2 on April 2) New Zealand and Australia
# ””
# ””
# ”” The United States has the fourth highest number of asylum
#
# [110 | 267.23] loss=2.11 avg=2.30
# [120 | 290.18] loss=1.77 avg=2.26
# [130 | 313.13] loss=1.49 avg=2.19
# [140 | 336.09] loss=1.68 avg=2.15
# [150 | 359.06] loss=1.20 avg=2.09
# [160 | 382.01] loss=1.24 avg=2.03
# [170 | 404.96] loss=0.83 avg=1.95
# [180 | 427.92] loss=1.09 avg=1.90
# [190 | 450.85] loss=1.23 avg=1.86
# [200 | 473.82] loss=1.12 avg=1.82
# ======== SAMPLE 1 ========
# rolog, which is known to precipitate severe side effects. But in a study in Brazil, where it has never before been linked to a pandemic, the researchers found that the vaccine was effective at killing off 90 percent of the animals vaccinated. The vaccine was prescribed to a small group of severely ill volunteers in a remote part of the country called Covaxa. A spokesman for the company that provides the vaccine never gave a specific reason for its use, and the lab reports no new cases of Covaxa. It is unlikely that the researchers will repeat the fiasco in China, where similar experiments failed to show that their vaccine wasn(�to). The pandemic has shown that vaccines can be very effective in killing off entire populations. In South Africa, where the vaccine trial began, a small trial began in July to herd immunity experiments in August. In that country, some participants received a coronavirus vaccine that coincided with their last known infection with no apparent effect on their immune systems. Immunity experiments repeatedly showed that the coronavirus vaccine combination worked well enough in combination with the vaccine. One of the volunteers took part in a study in which the participants were given two doses of an infectious coronavirus vaccine and two placebo. At the end of the second dose, the volunteers experienced a surge of antibodies while inhaling the virus vaccine. That study also showed that the vaccine didn’t cause weakened immune systems to make as many antibodies as had been expected. Vaccine companies believe the results are safe and contribute to millions of doses of vaccines worldwide. In January, the World Health Organization recommended that vaccines given in early childhood education be offered in 2,500 countries by the end of the year. Experts have since pointed to new benefits to both children and adolescents in taking advantage of these early vaccinations. In a report in October, children and adolescents were more likely than their elders to give the vaccines in large doses, and in certain subcultures, to become vaccinated. Experts have also shown that the vaccine is safe and effective in viruses and bacteria. Vaccines made by Johnson & Johnson and AstraZeneca have proven to be effective in animals and in many other experimental settings.  Researchers at the University of Washington have been developing vaccines for monkeys and humans for decades. Last spring, researchers at both universities forged a strong connection between the coronavirus and a remote agricultural community near Seattle, Washington. At a lab complex in Washington, D.C., researchers saw a possible link between an outbreak and a testing plant. They approached the lab owner and told him to get the plant tested on animals. The plant, called Nicotiana tabacum, has never before been reported to the Food and Drug Administration. Researchers then scaled back the plant’s production by two orders of magnitude. Researchers had hoped that if the F.D.A. knew about a new plant emerging from an agricultural operation, it might intervene and stop it. Instead, they feared the plant’s continued use. To make their vaccine, researchers started off with a more benign variant called BRP123, named for the crucible that holds the virus. They ran an open-label trial on about 15,000 volunteers, and on Nov. 19 they reported an 11 percent increase in antibodies produced by the BRP123 vaccine compared to placebo. The volunteers also received the placebo variant without the risk of the coronavirus spreading. Researchers now want to combine the two vaccines to give fewer side effects — like less blood clots and drowsiness — while still protecting against spike proteins in the vaccines. The BRP123 vaccine trials started on Jan. 25. On Feb. 22, the U.S. government announced that its approval of the BRP124 vaccine would be delayed for at least six weeks. New Jersey-based Vaxxia Biotechnology developed a vaccine based on genetically engineered Sputnik V cells cal ...
#
# [210 | 504.54] loss=0.89 avg=1.77
# [220 | 527.47] loss=0.96 avg=1.73
# [230 | 550.43] loss=0.42 avg=1.67
# [240 | 573.37] loss=0.89 avg=1.63
# [250 | 596.31] loss=0.64 avg=1.59
# [260 | 619.25] loss=1.14 avg=1.57
# [270 | 642.21] loss=0.70 avg=1.53
# [280 | 665.16] loss=0.43 avg=1.49
# [290 | 688.10] loss=0.59 avg=1.45
# [300 | 711.05] loss=0.19 avg=1.40
# ======== SAMPLE 1 ========
# , it can save lives.
# “This is the first vaccine trial in a series that will assess DeltaBac’s safety and how it will affect other emerging treatments. Researchers are also tailoring the trial to HIV/AIDs and emerging treatments, as well as older volunteers who were recruited through other means.
#
# 	The Phase 3 trial determined how well DeltaBac protects gorillas from the initial infection. For example, the trial found that the vaccine had an efficacy of 70 percent, and the immune response time of 28 percent. It also found that the vaccine did not cause the animals to suffer serious side effects.
#
# 	The researchers did not find any serious side effects in the volunteers who received the vaccine. This is in stark contrast to other experimental vaccines being tested in the lab.
#
# 	The researchers found that the vaccine has an efficacy of 55 percent against the full range of potential infection scenarios. On the other hand, the vaccine only slightly reduced the numbers of animals who received the vaccine.
#
# 	The researchers found that the vaccine had an efficacy of 71 percent against mild side effects, while the immune response time was just under 30 minutes.
#
# 	The researchers found that the vaccine had an efficacy of 68 percent against moderate side effects, while the immune response time was just under 35 minutes.
#  Note: Data are based on volunteer responses to the Pfizer-BioNTech vaccine and is taken from the company’s website.
#  A
# 	The small trial began as a clinical trial on gorillas in remote areas where herd immunity is not needed. In May, the company ditched that plan and launched a nationwide trial, eventually recruiting 2,000 volunteers. The trials offered important clues about the efficacy and safety of the Pfizer-BioNTech vaccine and its potential health benefits. But as the trial progressed, questions arose as to whether the preliminary evidence indicated that it was safe and effective.
#  Beginning in October, authorities in South Africa stopped short of endorsing the vaccine as the right vaccine for the emergency room response, despite the fact that the vaccine was given by the South African CEPF, the country’s leading provider of licensed flu vaccine.
#  Beginning in early 2020, researchers found that the vaccine did not cause symptoms in over 70% of volunteers. By the end of the trial, however, some volunteers reported feeling less and less well. Only a small number of volunteers received the vaccine.
#  The U.S. trial also found that the vaccine caused mild side effects. A small American study, for example, found that doses of Gabon 3 and 4 did not cause any serious side effects.
#  The trials are just one example of how the immune system handles new infections. Other potential vaccines include InovioVac and Vaxzevria.
#
# 	The evidence base in this case study is from a study suggesting that vaccines delivered into animals can neutralize some of the deleterious effects of their host.
#  Methodology The study involved some animal work, in which volunteers deliver the vaccine by mouth. Horses, for their part, have been running wild for years. In June, a European medical charity, the European Behavioural Trust, registered a survey to assess responses to a survey on veterinary health and attitudes. The survey, called ECHIV3 (exceptionally well designed and not designed to elicit any responses), was complete. Polls delivered using a hand-held device did not collect irrelevant information.  Participants were also asked to select a neutralizing agent, such as a virus. Source: European Commission, unpublished studies show that living together can have long-lasting health benefits. — Denise Yang, Baltimore City, Md. Eleanor Lai will be leaving California to become a caregiver for a rare but treatable blood disorder, her agent announced. Representatives for the Deaf and Other Under the Skin Coalition announced the announcement at the end of the day that Ms. Yang would be arriving home from an orientation at a social-services agency. — Sharon Efron Ph.D., director of the Coalition, said in a statement. — Gov. Gavin Newsom said he would sign legislation making it easier to get mental health services at risk settings. Hooray for community partnering for those living with discrimination. — Gabriel Giangallazzi Families gathering near their California home during the pandemic are gathering for the first time since it became a local event two
#
# [310 | 741.80] loss=0.60 avg=1.37
# [320 | 764.71] loss=0.50 avg=1.34
# [330 | 787.67] loss=0.28 avg=1.30
# [340 | 810.68] loss=0.16 avg=1.26
# [350 | 833.65] loss=0.39 avg=1.23
# [360 | 856.64] loss=0.38 avg=1.21
# [370 | 879.61] loss=0.47 avg=1.18
# [380 | 902.56] loss=0.29 avg=1.15
# [390 | 925.52] loss=0.49 avg=1.13
# [400 | 948.47] loss=0.37 avg=1.11
# Saving checkpoint/run_news/model-400

# %% [markdown]
# ## Loading a trained model and generating the text

# %%
def load_trained(d,s):
  gpt2.copy_checkpoint_from_gdrive(run_name='run_' + d)
  gpt2.load_gpt2(s, run_name='run_' + d)

# %%
def generate(d,s):
  gpt2.generate_to_file(s, run_name='run_' + d, destination_path = 'gen_' + d + '.txt', temperature = 0.7, nsamples = 100, length = 100) 
  gpt2.generate_to_file(s, run_name='run_' + d, destination_path = 'gen_' + d + '_abs.txt',  temperature = 0.7, nsamples = 10, length = 100, prefix = "Complex classification problems") 
  gpt2.generate_to_file(s, run_name='run_' + d, destination_path = 'gen_' + d + '_new.txt',  temperature = 0.7, nsamples = 10, length = 100, prefix = "Many argue that european policy of") 
  gpt2.generate_to_file(s, run_name='run_' + d, destination_path = 'gen_' + d + '_nov.txt',  temperature = 0.7, nsamples = 10, length = 100, prefix = "My eyes filled with tears") 
  gpt2.generate_to_file(s, run_name='run_' + d, destination_path = 'gen_' + d + '_neutral.txt',  temperature = 0.7, nsamples = 10, length = 100, prefix = "It is surprising")

# %%
session = gpt2.start_tf_sess()
load_trained('news', session)
generate('news', session)
# Out:
# Loading checkpoint checkpoint/run_news/model-400
# INFO:tensorflow:Restoring parameters from checkpoint/run_news/model-400

# %%
gpt2.generate(session, run_name='run_' + 'news',  temperature = 0.7, nsamples = 10, length = 100, prefix = "Complex classification problems")
# Out:
# Complex classification problems mean that even information about a child’s social class — a proxy for whether he or she is social — is not exact. Experts say there is scope for misclassification even in very poor countries. In a survey of 1,500 adults conducted for a newspaper in the Democratic Republic of the Congo in March, FIOS found that nearly three-quarters of the respondents had difficulty establishing their social class based on only a limited view of their nearest neighbors. Nearly half said they had difficulty establishing a
# ====================
# Complex classification problems allow us to store information about the people we want to interview at a time, but not what they say, except perhaps when they “” “SLAM!” or something along those lines. To make a request, contact a source listed below or come across our San Francisco office via our mobile app. We love hearing what you think about programming and ad tech, so feel free to let us know what you think. Also, if you decide to attend the conference, be sure
# ====================
# Complex classification problems in C won the trust of CEPI and other international standards agencies. The standards include those for standards in international trade unions and regional trade associations. The authoritative international standards organization the I.O. worldwide issued a similar assessment in December 2020. But the standards in many countries have yet to be revised. A new global standard, agreed at a summit in Qatar in December, aims to bring the standards of most countries by the end of the decade. The ambition: To be followed by everything from cell
# ====================
# Complex classification problems with some of the previously-named masks resulted in an accumulation of mask variants that are unlikely to be amplified by other means. To improve the signal-to-noise ratio, the researchers encoded the variants in their source code, combined them with a hint from a known variant, and passed the resulting signal to tuneVEC, a Signal Processing Unit at Apple. The company constructed an algorithmic algorithm that determined the variant’s variant-to-frequency correspondence by analyzing the pattern of the variant
# ====================
# Complex classification problems in C and C++
# In C, the keyword type system is a specialised programming language with many variants. It has influenced many fields of computer science, most prominently computer vision and information processing. In C, the keyword system is a specialised programming language (CLP). It has been used in a number of places, most notably as a keyword in C and as a part of the Standard for the Standardization of Common Lisp. In this paper, we will describe the canonical variants in C
# ====================
# Complex classification problems have led to a shortage of unclassified government data. The New York Times reported in May that the government had to publish nearly 6 million pages of C.D.C. records. The Times did not locate any C.D.C. complaint data that might be relevant to the forthcoming lawsuits. The government has not released the names of the companies that provide the C.D.C. Drugs database. Instead, it has withheld information about the C.D.C.'s compliance with federal
# ====================
# Complex classification problems, making it difficult to label data points as people without specific medical conditions. The company is building a database of more than 6,000 reports from the Centers for Disease Control and Prevention about the health of the United States. It is also developing a system to track down coronavirus cases and deaths based on where people live.On Aug. 18, UnitedHealth’s website reported that UnitedHealthcare had received approval to launch a trial of a DNA-based vaccine called ABNCoV-
# ====================
# Complex classification problems.
#  The canonical way to distribute the data is to put it in a database, maintain a mailing list, assign copies to knowledgeable researchers, distribute it among researchers in the field, tweet about it. This approach is not always cost-efficient, however. In the United States, the C.D.C. created a Web site for the annual coronavirus briefing, with an emphasis on emerging infections. They registered over 25 new infections in March, and by April they had reached 50 cases.
# ====================
# Complex classification problems mean that most people don’t even know they are in a virus until they get their dose. This can lead to terrible side effects, like fatigue, rashes and muscle aches. So many people are on a daily dose of a vaccine that it’s almost like a “wet'” day. It’s like taking a shower in the middle of the Spanish Inquisition. We’re living through a “Sesame Street” moment. Get
# ====================
# Complex classification problems in C Data Structures “The Data Science and Engineering Department has developed a novel combination of vector and inorganic particles for the first time. These particles can be embedded in anything from dirt to nanoparticle shells. They can also travel at speeds of light’s equivalent to helium. They’ll be the first particle-based medical device to reliably deliver a dose of an adjuvant to the human body, scientists announced on Dec. 20.” The developments at CERN and
# ====================
